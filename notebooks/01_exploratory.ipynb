# %% [markdown]
# # 01 - Exploratory Analysis
#
# Use the synthetic sample dataset to explore variable distributions and basic survival curves.
#
# `python
# import pandas as pd
# from pathlib import Path
#
# base = Path('..') / 'data' / 'sample'
# clinical = pd.read_csv(base / 'clinical.csv')
# lifestyle = pd.read_csv(base / 'lifestyle.csv')
# emb = pd.read_csv(base / 'imaging_embeddings.csv')
# outcomes = pd.read_csv(base / 'outcomes.csv')
#
# clinical.head()
# `
